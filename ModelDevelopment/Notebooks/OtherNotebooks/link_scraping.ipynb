# %% [markdown]
# # Generica web scraping notebook

# %%
# importing libraries

import csv 
import operator
import re
import threading

import sys

import requests
from tqdm import tqdm 
from bs4 import BeautifulSoup

from concurrent.futures import ThreadPoolExecutor
import concurrent

from urllib.parse import urlparse
from urllib.parse import urljoin

import spacy # we use this for word similarity

from collections import defaultdict
import random
import time

# %%
def get_base_url(url):
    try:
        parsed_url = urlparse(url)
        base_url = f"{parsed_url.scheme}://{parsed_url.netloc}"
        return base_url
    except Exception as e:
        # print(f"Error parsing URL {url}: {e}")
        return None

USER_AGENTS = [
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36",
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36",
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:79.0) Gecko/20100101 Firefox/79.0",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0.1 Safari/605.1.15",
]    

def get_data(url):
    headers = {"User-Agent": random.choice(USER_AGENTS)}  # Rotate user-agent

    try:
        response = requests.get(url, headers=headers, timeout=3)

        # Handle rate-limiting (HTTP 429) by pausing and retrying
        if response.status_code == 429:
            tqdm.write(f"FROM GET_DATA: Rate limit reached. Sleeping before retrying {url}")
            # print(f"FROM GET_DATA: Rate limit reached. Sleeping before retrying {url}")
            time.sleep(random.uniform(4, 8))  
            return get_data(url)

        if response.status_code == 200:
            return response.content  

        tqdm.write(f"FROM GET_DATA: Failed to retrieve {url}, Status Code: {response.status_code}")
        # print(f"FROM GET_DATA: Failed to retrieve {url}, Status Code: {response.status_code}")
        return None

    except requests.RequestException as e:
        tqdm.write(f"FROM GET_DATA: Error fetching {url}: {e}")
        # print(f"FROM GET_DATA: Error fetching {url}: {e}")
        return None

# %%
# reading the csv file and storing the links in the links list
links = [] # link
with open('../Data/furniture stores pages.csv', mode='r', newline='') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        origin = get_base_url(row[0])  # the trimmed url (the url is located in the first column)
        origin = origin + '/robots.txt'
        links.append((origin, row[0]))  
        

link_and_sitemap = []
for link in links:
    data = get_data(link[0])
    if data is not None:
        soup = BeautifulSoup(data, 'html.parser')
        for line in soup.get_text().split('\n'):
            if 'sitemap:' in line.lower():
                line = line[len("sitemap:"):]
                print(link[0], line)
                link_and_sitemap.append((link[0], line))
                break

print(len(link_and_sitemap))
# Out:
# FROM GET_DATA: Error fetching :///robots.txt: No connection adapters were found for ':///robots.txt'
# https://www.factorybuys.com.au/robots.txt  https://www.factorybuys.com.au/sitemap.xml
# https://dunlin.com.au/robots.txt  https://dunlin.com.au/sitemap.xml
# https://themodern.net.au/robots.txt  https://themodern.com.au/sitemap.xml
# C:\Users\boroz\AppData\Local\Temp\ipykernel_17600\2837550086.py:15: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(data, 'html.parser')
# https://hemisphereliving.com.au/robots.txt  https://hemisphereliving.com.au/sitemap_index.xml
# FROM GET_DATA: Error fetching https://home-buy.com.au/robots.txt: HTTPSConnectionPool(host='home-buy.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'home-buy.com.au'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://beckurbanfurniture.com.au/robots.txt: HTTPSConnectionPool(host='beckurbanfurniture.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA4203B0>: Failed to resolve 'beckurbanfurniture.com.au' ([Errno 11001] getaddrinfo failed)"))
# https://livingedge.com.au/robots.txt  https://www.livingedge.com.au/sitemap_index.xml
# https://edenliving.online/robots.txt  https://edenliving.online/sitemap.xml
# https://www.ourfurniturewarehouse.com.au/robots.txt  https://www.ourfurniturewarehouse.com.au/sitemap.xml
# https://cane-line.co.uk/robots.txt  https://cane-line.co.uk/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://haute-living.com/robots.txt, Status Code: 404
# https://www.knoll.com/robots.txt  https://www.knoll.com/sitemap.xml
# https://vastinterior.com.au/robots.txt  https://vastinterior.com.au/sitemap.xml
# https://www.hudsonfurniture.com.au/robots.txt  https://www.hudsonfurniture.com.au/sitemap.xml
# https://dhfonline.com/robots.txt  https://dhfonline.com/sitemap.xml
# FROM GET_DATA: Error fetching https://furnish123watertown.com/robots.txt: HTTPSConnectionPool(host='furnish123watertown.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'furnish123watertown.com'. (_ssl.c:1000)")))
# https://www.tandemarbor.com/robots.txt  https://www.tandemarbor.com/sitemap.xml
# https://www.perchfurniture.com/robots.txt  https://www.perchfurniture.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve http://www.vawayside.net/robots.txt, Status Code: 404
# https://curiousgrace.com.au/robots.txt  https://curiousgrace.com.au/sitemap.xml
# https://modshop1.com/robots.txt  https://modshop1.com/sitemap.xml
# https://www.scandesign.com/robots.txt  https://www.scandesign.com/sitemap.xml
# https://www.sofamania.com/robots.txt  https://www.sofamania.com/sitemap.xml
# https://www.fentonandfenton.com.au/robots.txt  https://www.fentonandfenton.com.au/sitemap.xml
# https://4-chairs.com/robots.txt  https://4-chairs.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://stationfurniture.store/robots.txt, Status Code: 404
# FROM GET_DATA: Failed to retrieve https://pinchdesign.com/robots.txt, Status Code: 404
# https://www.do-shop.com/robots.txt  https://www.do-shop.com/sitemap.xml
# https://claytongrayhome.com/robots.txt  https://claytongrayhome.com/sitemap.xml
# https://dfohome.com/robots.txt  https://a40507.sitemaphosting.com/3938508/sitemap.xml
# https://acmeshelving.com/robots.txt  https://acmeshelving.com/sitemap.xml
# https://www.kmpfurniture.com/robots.txt  http://www.kmpfurniture.com/sitemap.xml
# https://www.jseitz.com/robots.txt  https://www.jseitz.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.furnitureworldgalleries.com/robots.txt: HTTPSConnectionPool(host='www.furnitureworldgalleries.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA423800>: Failed to resolve 'www.furnitureworldgalleries.com' ([Errno 11002] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://www.homekoncepts.com/robots.txt: HTTPSConnectionPool(host='www.homekoncepts.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA421160>: Failed to resolve 'www.homekoncepts.com' ([Errno 11001] getaddrinfo failed)"))
# https://cityfurnitureshop.com/robots.txt  https://brooklyncityfurniture.com/sitemap.xml
# https://www.theguestroomfurniture.com/robots.txt  https://www.theguestroomfurniture.com/sitemap.xml
# https://www.danishinspirations.com/robots.txt  https://www.danishinspirations.com/sitemap_index.xml
# https://emfurn.com/robots.txt  https://emfurn.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://fmvegas.com/robots.txt, Status Code: 404
# FROM GET_DATA: Error fetching https://nicoyafurniture.com.au/robots.txt: HTTPSConnectionPool(host='nicoyafurniture.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C93E1CA0>: Failed to resolve 'nicoyafurniture.com.au' ([Errno 11001] getaddrinfo failed)"))
# https://galvinbrothers.co.uk/robots.txt  https://galvinbrothers.co.uk/sitemap.xml
# https://tyfinefurniture.com/robots.txt  https://www.tyfinefurniture.com/sitemap.xml
# https://24estyle.com/robots.txt  https://24estyle.com/sitemap.xml
# https://shopspencerfurnituresiouxfalls.com/robots.txt  https://shopspencerfurnituresiouxfalls.com/sitemap.xml
# https://bryantscountrystore.com/robots.txt  https://bryantscountrystore.com/sitemap.xml
# https://vincentdesign.com.au/robots.txt  https://vincentdesign.com.au/sitemap.xml
# https://magnolialane.biz/robots.txt  https://magnolialane.biz/sitemap.xml
# https://www.cranmorehome.com.au/robots.txt  https://www.cranmorehome.com.au/sitemap.xml
# https://www.vavoom.com.au/robots.txt  https://www.vavoom.com.au/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.goodwoodfurniture.com.au/robots.txt, Status Code: 404
# FROM GET_DATA: Failed to retrieve https://valentinesfurniture.com.au/robots.txt, Status Code: 404
# https://www.loungesplus.com.au/robots.txt  https://www.loungesplus.com.au/sitemap.xml
# https://www.yellowleafhammocks.com/robots.txt  https://www.yellowleafhammocks.com/sitemap.xml
# https://asplundstore.se/robots.txt  https://www.asplundstore.se/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://distinctive-interiors.com/robots.txt, Status Code: 403
# https://runyonsfinefurniture.com/robots.txt  https://runyonsfinefurniture.com/sitemap.xml
# https://karladubois.com/robots.txt  https://karladubois.com/sitemap.xml
# https://brownsquirrelfurniture.com/robots.txt  https://www.brownsquirrelfurniture.com/sitemap.xml
# https://viesso.com/robots.txt  https://viesso.com/sitemap.xml
# https://floydhome.com/robots.txt  https://floydhome.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.mybudgetfurniture.com/robots.txt: HTTPSConnectionPool(host='www.mybudgetfurniture.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.mybudgetfurniture.com'. (_ssl.c:1000)")))
# https://www.fiveelementsfurniture.com/robots.txt  https://www.fiveelementsfurniture.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://test-danish-inspirations.pantheonsite.io/robots.txt, Status Code: 530
# https://www.hipvan.com/robots.txt  https://www.hipvan.com/sitemaps/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://dev-danish-inspirations.pantheonsite.io/robots.txt, Status Code: 530
# FROM GET_DATA: Error fetching https://houseofhollingsworthblog.com/robots.txt: HTTPSConnectionPool(host='houseofhollingsworthblog.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C86727E0>: Failed to resolve 'houseofhollingsworthblog.com' ([Errno 11001] getaddrinfo failed)"))
# https://www.wardrobe-bunk-bed-sofa.uk/robots.txt  https://www.wardrobe-bunk-bed-sofa.uk/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://dwell.co.uk/robots.txt, Status Code: 403
# https://www.hopewells.co.uk/robots.txt  https://www.hopewells.co.uk/sitemap.xml
# https://kokocollective.com.au/robots.txt  https://kokocollective.com.au/sitemap.xml
# https://www.timothyoulton.com/robots.txt  https://www.timothyoulton.com/sitemap.xml
# https://www.warmnordic.com/robots.txt  https://warmnordic.com/sitemap.xml
# https://www.royaloakfurniture.co.uk/robots.txt  https://www.royaloakfurniture.co.uk/sitemap.xml
# https://mulamu.com/robots.txt  https://mulamu.com/sitemap.xml
# FROM GET_DATA: Error fetching http://www.genesisfurniturelv.com/robots.txt: HTTPConnectionPool(host='www.genesisfurniturelv.com', port=80): Read timed out. (read timeout=3)
# FROM GET_DATA: Failed to retrieve https://daufurniture.com/robots.txt, Status Code: 530
# https://www.waynesfinefurnitureandbedding.com/robots.txt  https://waynesfinefurnitureandbedding.com/sitemap.xml
# https://totalpatioaccessories.com/robots.txt  https://totalpatioaccessories.com/sitemap.xml
# https://www.groensfinefurniture.com/robots.txt  https://groensfinefurniture.com/sitemap_index.xml
# https://yesterdaystreefurniture.com/robots.txt  https://www.yesterdaystreefurniture.com/sitemap.xml
# https://www.jensen-lewis.com/robots.txt  https://www.jensen-lewis.com/sitemap.xml
# https://www.popandscott.com/robots.txt  https://www.popandscott.com/sitemap.xml
# https://shophorne.com/robots.txt  https://shophorne.com/sitemap.xml
# https://cultdesign.co.nz/robots.txt  https://cultdesign.co.nz/sitemap.xml
# https://www.gloster.com/robots.txt  https://www.gloster.com/sitemaps/gle.xml
# Disallow: /searchs%3d*%3fls%3d**&*filter*www.thebrick.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.altamodafurniture.com/robots.txt, Status Code: 403
# https://www.gowfb.com/robots.txt  https://www.gowfb.com/sitemap.xml
# https://allwoodfurn.com/robots.txt  https://allwoodfurn.com/sitemap.xml
# FROM GET_DATA: Error fetching https://decorum-shop.co.uk/robots.txt: HTTPSConnectionPool(host='decorum-shop.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'decorum-shop.co.uk'. (_ssl.c:1000)")))
# https://lostine.com/robots.txt  https://lostine.com/sitemap.xml
# https://designkollective.com/robots.txt  https://designkollective.com/sitemap.xml
# https://www.somedaydesigns.co.uk/robots.txt  https://www.somedaydesigns.co.uk/sitemap.xml
# https://www.mainecottage.com/robots.txt  https://www.mainecottage.com/sitemap.xml
# https://pawleysislandhammocks.com/robots.txt  https://a40507.sitemaphosting.com/3879541/sitemap.xml
# https://homeresource.com/robots.txt  https://homeresource.com/sitemap.xml
# https://www.antoninimodernliving.com/robots.txt  https://www.antoninimodernliving.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.shorehousefurniture.com/robots.txt, Status Code: 403
# FROM GET_DATA: Error fetching https://www.jandjtreasuretrove.net/robots.txt: HTTPSConnectionPool(host='www.jandjtreasuretrove.net', port=443): Read timed out. (read timeout=3)
# https://www.idcmn.com/robots.txt  https://www.idcmn.com/sitemap.xml
# FROM GET_DATA: Error fetching https://calligarisla.com/robots.txt: HTTPSConnectionPool(host='calligarisla.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C91951C0>: Failed to resolve 'calligarisla.com' ([Errno 11001] getaddrinfo failed)"))
# https://stealasofa.com/robots.txt  https://furniturecasalinda.com/sitemap.xml
# https://urbanfurnishing.net/robots.txt  https://urbanfurnishing.net/sitemap.xml
# https://vancouverwoodworks.com/robots.txt  https://vancouverwoodworks.com/sitemap.xml
# https://www.kannoa.com/robots.txt  https://www.kannoa.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.furnituremarts.com/robots.txt: HTTPSConnectionPool(host='www.furnituremarts.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.furnituremarts.com'. (_ssl.c:1000)")))
# https://osmen.com.au/robots.txt  https://osmen.com.au/sitemap.xml
# https://www.thefurnituremegastore.co.uk/robots.txt  https://www.thefurnituremegastore.co.uk/sitemap.xml
# https://contempoconcepts.com/robots.txt  https://contempoconcepts.com/sitemap.xml
# https://eurolivingfurniture.com/robots.txt  https://eurolivingfurniture.com/sitemap.xml
# https://sarahellison.com.au/robots.txt  https://ellisonstudios.com/sitemap.xml
# https://oakspecialists.com/robots.txt  https://www.oakspecialists.com/sitemap.xml
# https://midinmod.com/robots.txt  https://midinmod.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.unclaimed-furniture.com/robots.txt, Status Code: 403
# FROM GET_DATA: Error fetching http://www.kis-lv.com/robots.txt: HTTPConnectionPool(host='www.kis-lv.com', port=80): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000204C9364F20>: Failed to resolve 'www.kis-lv.com' ([Errno 11001] getaddrinfo failed)"))
# https://wayborn.com/robots.txt  https://wayborn.com/wp-sitemap.xml
# https://www.bovafurniture.com/robots.txt  https://www.bovafurniture.com/wp-sitemap.xml
# https://hauslondon.com/robots.txt  https://hauslondon.com/sitemap.xml
# https://allworldfurniture.com/robots.txt  https://allworldfurniture.com/wp-sitemap.xml
# https://decorium.us/robots.txt  https://decorium.us/sitemap.xml
# https://www.softsquare.com/robots.txt  https://www.softsquare.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.rockymountain.furniture/robots.txt, Status Code: 403
# FROM GET_DATA: Failed to retrieve https://www.statewidefurniture.com/robots.txt, Status Code: 403
# https://huckandpeck.com/robots.txt  https://huckandpeck.com/sitemap.xml
# https://najarianfurniture.com/robots.txt  https://najarianfurniture.com/sitemap.xml
# https://qualitywoods.com/robots.txt  https://qualitywoods.com/sitemap.xml
# FROM GET_DATA: Error fetching https://mybossfurniture.com/robots.txt: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# FROM GET_DATA: Error fetching https://www.furnish123quadcities.com/robots.txt: HTTPSConnectionPool(host='www.furnish123quadcities.com', port=443): Read timed out. (read timeout=3)
# https://americanbackyard.com/robots.txt  https://www.americanbackyard.com/sitemap.xml
# https://www.roccityfurniture.com/robots.txt  https://www.roccityfurniture.com/sitemap.xml
# https://www.sutherlandfurniture.com/robots.txt  https://www.sutherlandfurniture.com/sitemap_index.xml
# https://craftassociatesfurniture.com/robots.txt  https://craftassociatesfurniture.com/sitemap.xml
# https://huset-shop.com/robots.txt  https://huset-shop.com/sitemap.xml
# https://www.scotmeachamwoodhome.com/robots.txt  https://www.scotmeachamwoodhome.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.espasso.com/robots.txt, Status Code: 404
# https://sika-design.com/robots.txt  https://sika-design.com/sitemap.xml
# https://thebellacottage.com/robots.txt  https://thebellacottage.com/sitemap.xml
# https://www.skandium.com/robots.txt  https://www.skandium.com/sitemap.xml
# https://www.woodwaves.com/robots.txt  https://www.woodwaves.com/sitemap.xml
# https://sjotime.com/robots.txt  https://sjotime.com/sitemap.xml
# https://littlepartners.com/robots.txt  https://littlepartners.com/sitemap.xml
# https://jeremiahcollection.com/robots.txt  https://jeremiahcollection.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.shoptorious.com/robots.txt, Status Code: 404
# https://thefinestore.com/robots.txt  https://thefinestore.com/sitemap.xml
# http://oot-oot.com/robots.txt  https://oot-oot.com/sitemap.xml
# https://lorfords.com/robots.txt  https://lorfords.com/sitemap.xml
# https://www.arighibianchi.co.uk/robots.txt  https://www.arighibianchi.co.uk/sitemap.xml
# https://idlehands.design/robots.txt  https://idlehands.design/sitemap.xml
# FROM GET_DATA: Error fetching https://www.diyfurniturestore.com/robots.txt: HTTPSConnectionPool(host='www.diyfurniturestore.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.diyfurniturestore.com'. (_ssl.c:1000)")))
# https://pastperfect.sg/robots.txt  https://pastperfect.sg/sitemap_index.xml
# FROM GET_DATA: Error fetching https://bastilleandsons.com.au/robots.txt: HTTPSConnectionPool(host='bastilleandsons.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C93662A0>: Failed to resolve 'bastilleandsons.com.au' ([Errno 11001] getaddrinfo failed)"))
# https://classicwithatwist.com.au/robots.txt  https://classicwithatwist.com.au/sitemap.xml
# https://apato.com.au/robots.txt  https://apato.com.au/sitemap.xml
# https://thewoodroom.com.au/robots.txt  https://thewoodroom.com.au/sitemap.xml
# https://thebanyantree.com.au/robots.txt  https://thebanyantree.com.au/sitemap.xml
# https://ardoutdoor.com/robots.txt  https://ardoutdoor.com/sitemap_index.xml
# https://hauserstores.com/robots.txt  https://hauserstores.com/sitemap.xml
# https://boahaus.com/robots.txt  https://boahaus.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://tabularasa-furniture.com/robots.txt, Status Code: 403
# https://livingbydesign.net.au/robots.txt  https://livingbydesign.net.au/sitemap.xml
# https://www.living-home.co.uk/robots.txt  https://www.living-home.co.uk/sitemap.xml
# https://relm.com.au/robots.txt  https://relm.com.au/sitemap.xml
# FROM GET_DATA: Error fetching https://www.harpersproject.com/robots.txt: HTTPSConnectionPool(host='www.harpersproject.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9196AB0>: Failed to resolve 'www.harpersproject.com' ([Errno 11002] getaddrinfo failed)"))
# https://www.morningstartrading.ca/robots.txt  https://www.morningstartrading.ca/sitemap.xml
# FROM GET_DATA: Error fetching https://www.bellus.com/robots.txt: HTTPSConnectionPool(host='www.bellus.com', port=443): Read timed out. (read timeout=3)
# https://www.hatihome.com/robots.txt  https://www.hatihome.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.meta44.com/robots.txt: HTTPSConnectionPool(host='www.meta44.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000204C9367E30>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# https://modernkomfort.ca/robots.txt  https://modernkomfort.ca/sitemap.xml
# https://www.aarniooriginals.com/robots.txt  https://www.aarniooriginals.com/sitemap.xml
# https://chansfurniture.com/robots.txt  https://chansfurniture.com/sitemap.xml
# https://alasaw.com/robots.txt  https://alasaw.com/sitemap.xml
# https://hedgehousefurniture.com/robots.txt  https://hedgehousefurniture.com/sitemap.xml
# http://www.mountainteak.com/robots.txt  https://www.mountainteak.com/1_index_sitemap.xml
# https://www.lestudiolum.com/robots.txt  https://www.lestudiolum.com/sitemap.xml
# https://www.ameriwoodhome.com/robots.txt  https://www.ameriwoodhome.com/sitemap.xml
# https://www.homeandstyle.com.sg/robots.txt  https://www.homeandstyle.com.sg/sitemap.xml
# https://shop.vanillawood.com/robots.txt  https://shop.vanillawood.com/sitemap.xml
# http://modliving.com.ph/robots.txt  https://modliving.com.ph/wp-sitemap.xml
# FROM GET_DATA: Error fetching https://curiocavern.ph/robots.txt: HTTPSConnectionPool(host='curiocavern.ph', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'curiocavern.ph'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://www.mossmanilahome.com/robots.txt: HTTPSConnectionPool(host='www.mossmanilahome.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9196930>: Failed to resolve 'www.mossmanilahome.com' ([Errno 11001] getaddrinfo failed)"))
# https://oakforless.com/robots.txt  https://oakforless.com/sitemap.xml
# https://www.castlery.com/robots.txt  https://www.castlery.com/sg/sitemap.xml
# https://www.getmycouch.com/robots.txt  https://www.getmycouch.com/sitemap.xml
# https://www.castlery.com.au/robots.txt  https://www.castlery.com/sg/sitemap.xml
# https://homestreethome.ie/robots.txt  https://homestreethome.ie/sitemap.xml
# https://www.myconcept.com.hk/robots.txt  https://www.myconcept.com.hk/sitemap.xml
# FROM GET_DATA: Error fetching https://newforestrusticfurniture.co.uk/robots.txt: HTTPSConnectionPool(host='newforestrusticfurniture.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'newforestrusticfurniture.co.uk'. (_ssl.c:1000)")))
# https://vauntdesign.com/robots.txt  https://vauntdesign.com/sitemap.xml
# https://www.langria.com/robots.txt  https://langria.com/sitemap_index.xml
# https://www.kolocollection.com/robots.txt  https://www.kolocollection.com/sitemap.xml
# https://asianteakfurniture.com/robots.txt  https://asianteakfurniture.com/sitemap.xml
# https://furnitica-vinova.myshopify.com/robots.txt  https://furnitica-vinova.myshopify.com/sitemap.xml
# https://jordanshome.ca/robots.txt  https://jordanshome.ca/sitemap.xml
# https://mikazahome.ca/robots.txt  https://mikazahome.ca/sitemap_index.xml
# https://barnabylane.com.au/robots.txt  https://barnabylane.com.au/sitemap.xml
# https://urbangalleria.com/robots.txt  https://urbangalleria.com/sitemap.xml
# https://www.modernfurniture.com.au/robots.txt  https://www.modernfurniture.com.au/sitemap.xml
# https://www.granitelane.com.au/robots.txt  https://www.granitelane.com.au/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://teak-furniture-singapore.com/robots.txt, Status Code: 423
# https://teak-warehouse-sale.com/robots.txt  https://teak-warehouse-sale.com/sitemap.xml
# https://www.countrysideamishfurniture.com/robots.txt  http://www.countrysideamishfurniture.com/sitemap-categories
# https://www.modishstore.com/robots.txt  https://www.modishstore.com/sitemap.xml
# https://www.stylemyhome.com.au/robots.txt  https://www.stylemyhome.com.au/sitemap.xml
# https://loft-theme-demo-nashville.myshopify.com/robots.txt  https://loft-theme-demo-nashville.myshopify.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://teakco.com/robots.txt, Status Code: 423
# https://www.skovby.com/robots.txt  https://www.skovby.com/Sitemap.xml
# https://boulevardoutdoorfurniture.com/robots.txt  https://boulevardoutdoorfurniture.com/sitemap.xml
# https://big-sale-furniture.com/robots.txt  https://big-sale-furniture.com/sitemap.xml
# https://taktcph.com/robots.txt  https://taktcph.com/sitemap_index.xml
# https://www.blackmango.com.au/robots.txt  https://www.blackmango.com.au/sitemap.xml
# https://candb.ca/robots.txt  https://candb.ca/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.oopenspace.com/robots.txt, Status Code: 404
# FROM GET_DATA: Failed to retrieve http://gharwakhri.com/robots.txt, Status Code: 404
# FROM GET_DATA: Failed to retrieve https://thonet.co.nz/robots.txt, Status Code: 404
# FROM GET_DATA: Error fetching https://www.nigbursfinefurniture.com/robots.txt: HTTPSConnectionPool(host='www.nigbursfinefurniture.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.nigbursfinefurniture.com'. (_ssl.c:1000)")))
# https://brownandbeam.com/robots.txt  https://brownandbeam.com/sitemap.xml
# https://taeillo.com/robots.txt  https://taeillo.com/sitemap.xml
# https://zenchair.co.za/robots.txt  https://www.zenchair.co.za/sitemap.xml
# https://vintage-etc.com/robots.txt  https://vintage-etc.com/sitemap.xml
# https://www.youngath-art.com/robots.txt  https://www.youngath-art.com/sitemap.xml
# https://www.hamac-shop.be/robots.txt  https://www.hamac-shop.be/sitemap.xml
# https://www.masayacompany.com/robots.txt  https://www.masayacompany.com/sitemap.xml
# https://ikonitaly.com/robots.txt  https://www.ikonitaly.com/sitemap.xml
# https://arkaliving.com/robots.txt  https://arkaliving.com/sitemap.xml
# FROM GET_DATA: Error fetching https://inliving.com/robots.txt: HTTPSConnectionPool(host='inliving.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# https://waltercox.co.uk/robots.txt  https://www.waltercox.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://davidsfurniture.com/robots.txt: HTTPSConnectionPool(host='davidsfurniture.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'davidsfurniture.com'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://www.fdxonline.com/robots.txt: HTTPSConnectionPool(host='www.fdxonline.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C91961E0>: Failed to resolve 'www.fdxonline.com' ([Errno 11001] getaddrinfo failed)"))
# https://www.212concept.com/robots.txt  https://www.212concept.com/sitemap.xml
# https://www.stacksfurniture.co.nz/robots.txt  https://www.stacksfurniture.co.nz/sitemap.xml
# https://vintagehomeboutique.ca/robots.txt  https://vintagehomeboutique.ca/sitemap.xml
# https://bydesignmodern.com/robots.txt  https://bydesignmodern.com/sitemap.xml
# https://www.couchpotatocompany.com/robots.txt  https://www.couchpotatocompany.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.bfelix.com/robots.txt: HTTPSConnectionPool(host='www.bfelix.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bfelix.com'. (_ssl.c:1000)")))
# https://www.laura-james.co.uk/robots.txt  https://www.laura-james.co.uk/sitemap.xml
# https://mossgardenhome.com/robots.txt  https://mossgardenhome.com/sitemap.xml
# https://www.amcfurniture.co.uk/robots.txt  https://www.amcfurniture.co.uk/sitemap.xml
# https://timelessdesign.com.my/robots.txt  https://timelessdesign.com.my/sitemap.xml
# https://atomi.shop/robots.txt  https://atomi.shop/sitemap.xml
# FROM GET_DATA: Error fetching https://www.houzzconcept.com.au/robots.txt: HTTPSConnectionPool(host='www.houzzconcept.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9A34620>: Failed to resolve 'www.houzzconcept.com.au' ([Errno 11001] getaddrinfo failed)"))
# https://lesa.com.my/robots.txt  https://lesa.com.my/wp-sitemap.xml
# FROM GET_DATA: Error fetching https://kenittifurniture.com/robots.txt: HTTPSConnectionPool(host='kenittifurniture.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C91956D0>: Failed to resolve 'kenittifurniture.com' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Failed to retrieve https://www.mfdesign.com.my/robots.txt, Status Code: 404
# https://nyfurnitureoutlets.com/robots.txt  https://nyfurnitureoutlets.com/sitemap_index.xml
# https://www.mydiscountmalta.com/robots.txt  https://www.mydiscountmalta.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve http://www.muuduufurniture.com/robots.txt, Status Code: 404
# https://ifurnituresupply.com/robots.txt  https://ifurnituresupply.com/sitemap.xml
# https://lazysusansusa.com/robots.txt  https://lazysusansusa.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.pacificlifestyledecor.com/robots.txt: HTTPSConnectionPool(host='www.pacificlifestyledecor.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9196330>: Failed to resolve 'www.pacificlifestyledecor.com' ([Errno 11001] getaddrinfo failed)"))
# https://www.willowcreekteak.com/robots.txt  https://www.willowcreekteak.com/sitemap.xml
# https://www.furnitureworldsaskatoon.com/robots.txt  http://furnitureworldsaskatoon.com/sitemap_index.xml
# https://hklivingusa.com/robots.txt  https://hklivingusa.com/sitemap.xml
# https://scenicdecor.ca/robots.txt  https://www.scenicdecor.ca/sitemap.xml
# FROM GET_DATA: Error fetching https://rusticcraft.ca/robots.txt: HTTPSConnectionPool(host='rusticcraft.ca', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'rusticcraft.ca'. (_ssl.c:1000)")))
# https://rusteak.com/robots.txt  https://www.rusteak.com/sitemap.xml
# https://www.ambersfurniture.com/robots.txt  https://www.ambersfurniture.com/sitemap.xml
# https://fredericksgallery.ca/robots.txt  https://fredericksgallery.ca/sitemap.xml
# https://www.18karatstore.com/robots.txt  https://www.18karatstore.com/sitemap.xml
# FROM GET_DATA: Error fetching https://mesasilla.ca/robots.txt: HTTPSConnectionPool(host='mesasilla.ca', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9195970>: Failed to resolve 'mesasilla.ca' ([Errno 11002] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://www.herashome.com/robots.txt: HTTPSConnectionPool(host='www.herashome.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.herashome.com'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://minimalandmodern.ca/robots.txt: HTTPSConnectionPool(host='minimalandmodern.ca', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9A341D0>: Failed to resolve 'minimalandmodern.ca' ([Errno 11001] getaddrinfo failed)"))
# https://www.equilibriumfurnishings.com/robots.txt  https://www.equilibriumfurnishings.com/sitemap.xml
# FROM GET_DATA: Error fetching https://htinteriors.ca/robots.txt: HTTPSConnectionPool(host='htinteriors.ca', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9B2F620>: Failed to resolve 'htinteriors.ca' ([Errno 11001] getaddrinfo failed)"))
# https://mildanmarket.com/robots.txt  https://mildanmarket.com/sitemap.xml
# https://treaclegeorge.com/robots.txt  https://treaclegeorge.com/sitemap.xml
# http://veranda.com.au/robots.txt  User-agent: *
# FROM GET_DATA: Failed to retrieve http://thomsonfurnitureonline.com/robots.txt, Status Code: 404
# FROM GET_DATA: Error fetching https://boneinlayhome.com.au/robots.txt: HTTPSConnectionPool(host='boneinlayhome.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'boneinlayhome.com.au'. (_ssl.c:1000)")))
# https://www.insaraf.com/robots.txt  https://www.insaraf.com/sitemap.xml
# https://homedesignstoreflorida.com/robots.txt  https://homedesignstoreflorida.com/sitemap.xml
# https://www.lakkadhaara.com/robots.txt  https://www.lakkadhaara.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.kid2youth.in/robots.txt: HTTPSConnectionPool(host='www.kid2youth.in', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9196210>: Failed to resolve 'www.kid2youth.in' ([Errno 11001] getaddrinfo failed)"))
# https://www.nsquarestudio.com/robots.txt  https://www.nsquarestudio.com/sitemap.xml
# https://lovenlight.eu/robots.txt  https://lovenlight.eu/sitemap_index.xml
# http://www.komodromos.com.cy/robots.txt  http://www.komodromos.com.cy/sitemap_index.xml
# https://bedesign.fi/robots.txt  https://bedesign.fi/sitemap.xml
# https://scanteak.com.sg/robots.txt  https://scanteak.com.sg/sitemap.xml
# FROM GET_DATA: Error fetching https://www.elementsconcept.com.sg/robots.txt: HTTPSConnectionPool(host='www.elementsconcept.com.sg', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.elementsconcept.com.sg'. (_ssl.c:1000)")))
# http://roomyroom.com/robots.txt  https://roomyroom.com/sitemap.xml
# https://www.finnavenue.com/robots.txt  https://www.finnavenue.com/sitemap.xml
# https://singaporetradingpost.com/robots.txt  https://singaporetradingpost.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://singapore-furniture-sale.com/robots.txt, Status Code: 423
# https://www.ministryofchair.com/robots.txt  https://www.ministryofchair.com/sitemap.xml
# https://1outdoorfurniture.com/robots.txt  https://1outdoorfurniture.com/sitemap.xml
# https://wholesaleclassicfurniture.com/robots.txt  https://wholesaleclassicfurniture.com/sitemap.xml
# https://www.novena.com.sg/robots.txt  https://www.novena.com.sg/sitemap.xml
# FROM GET_DATA: Error fetching https://taylorbdesign.com/robots.txt: HTTPSConnectionPool(host='taylorbdesign.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'taylorbdesign.com'. (_ssl.c:1000)")))
# https://houseofanli.com/robots.txt  https://houseofanli.com/sitemap.xml
# https://hemma.sg/robots.txt  https://hemma.sg/sitemap.xml
# https://wholesaleteakcompany.com/robots.txt  https://wholesaleteakcompany.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.bibliotek.co/robots.txt: HTTPSConnectionPool(host='www.bibliotek.co', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bibliotek.co'. (_ssl.c:1000)")))
# https://warehaus.sg/robots.txt  http://warehaus.sg/sitemap.xml
# FROM GET_DATA: Error fetching https://home99.sg/robots.txt: HTTPSConnectionPool(host='home99.sg', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C91961E0>: Failed to resolve 'home99.sg' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://hmezsofa.sg/robots.txt: HTTPSConnectionPool(host='hmezsofa.sg', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9195580>: Failed to resolve 'hmezsofa.sg' ([Errno 11001] getaddrinfo failed)"))
# https://www.nookandcranny.com/robots.txt  https://www.nookandcranny.com/sitemap.xml
# https://www.vetrohome.com/robots.txt  https://www.vetrohome.com/sitemap.xml
# https://www.gowanusfurniture.com/robots.txt  https://www.gowanusfurniture.com/sitemap.xml
# FROM GET_DATA: Error fetching https://epilog.co.id/robots.txt: HTTPSConnectionPool(host='epilog.co.id', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'epilog.co.id'. (_ssl.c:1000)")))
# https://gingerjarfurniture.com/robots.txt  https://gingerjarfurniture.com/wp-sitemap.xml
# FROM GET_DATA: Failed to retrieve https://solidaustin.com/robots.txt, Status Code: 404
# https://alteriors.ca/robots.txt  https://alteriors.ca/sitemap.xml
# http://www.italiafurniture.com/robots.txt  https://italiafurniture.com/sitemap.xml
# https://onske.co.uk/robots.txt  https://onske.co.uk/sitemap.xml
# https://ilrestaurato.com/robots.txt  https://ilrestaurato.com/sitemap.xml
# https://www.eurohausfurniture.com/robots.txt  https://eurohausfurniture.com/sitemap.xml
# https://www.ultimateliving.co.nz/robots.txt  https://ultimateliving.co.nz/sitemap.xml
# https://www.rimufurniture.co.nz/robots.txt  https://www.rimufurniture.co.nz/sitemap_index.xml
# https://www.zavedo.nz/robots.txt  https://www.zavedo.nz/sitemap.xml
# FROM GET_DATA: Error fetching https://polini.co.nz/robots.txt: HTTPSConnectionPool(host='polini.co.nz', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'polini.co.nz'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://basefurniture.co.nz/robots.txt: HTTPSConnectionPool(host='basefurniture.co.nz', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9195310>: Failed to resolve 'basefurniture.co.nz' ([Errno 11001] getaddrinfo failed)"))
# https://www.hammockshop.co.nz/robots.txt  https://www.hammockshop.co.nz/sitemap.xml
# FROM GET_DATA: Error fetching https://www.attichomestore.co.nz/robots.txt: HTTPSConnectionPool(host='www.attichomestore.co.nz', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA529700>: Failed to resolve 'www.attichomestore.co.nz' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://urban-beach.co.nz/robots.txt: HTTPSConnectionPool(host='urban-beach.co.nz', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA422C30>: Failed to resolve 'urban-beach.co.nz' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Failed to retrieve https://countrylife.co.nz/robots.txt, Status Code: 401
# https://www.corcovado.co.nz/robots.txt  https://www.corcovado.co.nz/sitemap.xml
# https://www.lujo.co.nz/robots.txt  https://www.lujo.co.nz/sitemap.xml
# https://www.lujoliving.com/robots.txt  https://lujoliving.com/sitemap.xml
# https://www.shopden-la.com/robots.txt  https://www.shopden-la.com/sitemap.xml
# https://wrightsfurnitures.com/robots.txt  https://wrightsfurnitures.com/wp-sitemap.xml
# FROM GET_DATA: Error fetching https://bohovalley.com.au/robots.txt: HTTPSConnectionPool(host='bohovalley.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9197BC0>: Failed to resolve 'bohovalley.com.au' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://www.lounj.com.au/robots.txt: HTTPSConnectionPool(host='www.lounj.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9197560>: Failed to resolve 'www.lounj.com.au' ([Errno 11001] getaddrinfo failed)"))
# https://sofasandmore.co.nz/robots.txt  https://sofasandmore.co.nz/sitemap.xml
# FROM GET_DATA: Error fetching https://australianchildrensfurniture.com.au/robots.txt: HTTPSConnectionPool(host='australianchildrensfurniture.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9195760>: Failed to resolve 'australianchildrensfurniture.com.au' ([Errno 11001] getaddrinfo failed)"))
# https://www.bandhinidesign.com/robots.txt  https://www.bandhinidesign.com/sitemap.xml
# https://www.case22.com.au/robots.txt  https://www.case22.com.au/sitemap.xml
# FROM GET_DATA: Error fetching https://www.kwikshopnship.com.au/robots.txt: HTTPSConnectionPool(host='www.kwikshopnship.com.au', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.kwikshopnship.com.au'. (_ssl.c:1000)")))
# https://modernhomefurniture.com.au/robots.txt  https://modernhomefurniture.com.au/sitemap.xml
# https://nestz.com.au/robots.txt  https://momentousliving.com.au/sitemap.xml
# https://kubekfurniture.com/robots.txt  https://kubekfurniture.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://www.koernerfurniture.com/robots.txt, Status Code: 403
# FROM GET_DATA: Error fetching https://razoutlets.com/robots.txt: HTTPSConnectionPool(host='razoutlets.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA4229F0>: Failed to resolve 'razoutlets.com' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://all3loops.com/robots.txt: HTTPSConnectionPool(host='all3loops.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9195280>: Failed to resolve 'all3loops.com' ([Errno 11001] getaddrinfo failed)"))
# https://augustusbrandt.co.uk/robots.txt  https://augustusbrandt.co.uk/sitemap.xml
# https://www.zipchair.com/robots.txt  https://www.zipchair.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://gousesfurniture.com/robots.txt, Status Code: 403
# https://maximahouse.com/robots.txt  https://maximahouse.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.conceptuscollection.com/robots.txt: HTTPSConnectionPool(host='www.conceptuscollection.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.conceptuscollection.com'. (_ssl.c:1000)")))
# https://woodaction.com/robots.txt  https://woodaction.com/sitemap.xml
# https://homesteadfurniturebc.com/robots.txt  https://homesteadfurniturebc.com/sitemap.xml
# https://popstrukt.com/robots.txt  https://popstrukt.com/sitemap.xml
# https://dkmodernfurniture.com/robots.txt  https://dkmodernfurniture.com/sitemap.xml
# FROM GET_DATA: Error fetching https://woodtribe.co.nz/robots.txt: HTTPSConnectionPool(host='woodtribe.co.nz', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9194DD0>: Failed to resolve 'woodtribe.co.nz' ([Errno 11001] getaddrinfo failed)"))
# https://www.project82.com.au/robots.txt  https://project82.com.au/wp-sitemap.xml
# http://position-collective.com/robots.txt  https://position-collective.com/wp-sitemap.xml
# FROM GET_DATA: Error fetching https://www.jaimesfurniture.com/robots.txt: HTTPSConnectionPool(host='www.jaimesfurniture.com', port=443): Max retries exceeded with url: /robots.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000204C9197350>, 'Connection to www.jaimesfurniture.com timed out. (connect timeout=3)'))
# FROM GET_DATA: Failed to retrieve https://driftingwood.in/robots.txt, Status Code: 404
# https://studioydesign.ca/robots.txt  https://studioydesign.ca/sitemap.xml
# https://pure-patio.com/robots.txt  https://pure-patio.com/sitemap.xml
# https://jubileefurniturelv.com/robots.txt  https://jubileefurniturelv.com/sitemap.xml
# FROM GET_DATA: Error fetching https://www.skyhomedecor.com/robots.txt: HTTPSConnectionPool(host='www.skyhomedecor.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.skyhomedecor.com'. (_ssl.c:1000)")))
# https://interiorsinvogue.com/robots.txt  https://interiorsinvogue.com/sitemap.xml
# FROM GET_DATA: Error fetching https://elegantoak.co.uk/robots.txt: HTTPSConnectionPool(host='elegantoak.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'elegantoak.co.uk'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://emvy.gr/robots.txt: HTTPSConnectionPool(host='emvy.gr', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C9A371D0>: Failed to resolve 'emvy.gr' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://em-say.com/robots.txt: HTTPSConnectionPool(host='em-say.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'em-say.com'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://houseofdurante.co.uk/robots.txt: HTTPSConnectionPool(host='houseofdurante.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'houseofdurante.co.uk'. (_ssl.c:1000)")))
# https://shop-ames-interiors.com/robots.txt  https://shop-ames-interiors.com/sitemap_index.xml
# https://ezzo.co.uk/robots.txt  https://ezzo.co.uk/sitemap.xml
# https://sakhome.co.uk/robots.txt  https://sakhome.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://www.astellahrela.com/robots.txt: HTTPConnectionPool(host='vrshen.com', port=80): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000204C9392DB0>: Failed to resolve 'vrshen.com' ([Errno 11002] getaddrinfo failed)"))
# https://huxlo.co.uk/robots.txt  https://huxlo.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://centralcoastfurniture.com/robots.txt: HTTPSConnectionPool(host='centralcoastfurniture.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'centralcoastfurniture.com'. (_ssl.c:1000)")))
# https://mandai-design.com/robots.txt  https://www.mandai-design.com/sitemap.xml
# https://www.furnituresales.com.au/robots.txt  https://www.furnituresales.com.au/sitemap.xml
# https://www.jarrahmarri.com.au/robots.txt  https://www.directfurniturewa.com.au/sitemap.xml
# https://www.henryandoliverco.com/robots.txt  https://www.henryandoliverco.com/sitemap.xml
# https://avehome.com/robots.txt  https://avehome.com/sitemap.xml
# https://elephanthead.co.uk/robots.txt  https://elephanthead.co.uk/sitemap.xml
# https://www.mantrafurnishings.com/robots.txt  https://www.mantrafurnishings.com/sitemap.xml
# https://www.coolstuffandaccessories.com/robots.txt  https://www.coolstuffandaccessories.com/sitemap.xml
# FROM GET_DATA: Error fetching https://thecooldepot.com/robots.txt: HTTPSConnectionPool(host='thecooldepot.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C93913A0>: Failed to resolve 'thecooldepot.com' ([Errno 11001] getaddrinfo failed)"))
# ...
# FROM GET_DATA: Error fetching https://www.sartra.co.uk/robots.txt: HTTPSConnectionPool(host='www.sartra.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.sartra.co.uk'. (_ssl.c:1000)")))
# FROM GET_DATA: Failed to retrieve https://shannonsales.co.uk/robots.txt, Status Code: 404
# https://settlehome.co.uk/robots.txt  https://settlehome.co.uk/sitemap.xml
# https://www.simplyhammocks.co.uk/robots.txt  https://www.simplyhammocks.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://www.solidoakfurniture.co.uk/robots.txt: HTTPSConnectionPool(host='www.solidoakfurniture.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.solidoakfurniture.co.uk'. (_ssl.c:1000)")))
# https://tiffanyjayne.co.uk/robots.txt  https://tiffanyjayne.co.uk/sitemap.xml
# https://www.whytesofcrossgar.co.uk/robots.txt  https://www.whytesofcrossgar.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://glenwoodfurnishings.co.uk/robots.txt: HTTPSConnectionPool(host='glenwoodfurnishings.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'glenwoodfurnishings.co.uk'. (_ssl.c:1000)")))
# https://furniturebylauren.co.uk/robots.txt  https://furniturebylauren.co.uk/sitemap_index.xml
# https://lloydloom-uk.co.uk/robots.txt  https://lloydloom-uk.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://www.royalcraft.co.uk/robots.txt: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# https://www.fireandco.co.uk/robots.txt  https://www.cointeriors.co.uk/sitemap.xml
# https://www.askewsfurniture.co.uk/robots.txt  https://www.askewsfurniture.co.uk/sitemap.xml
# https://www.theattikstannes.co.uk/robots.txt  https://www.theattikstannes.co.uk/sitemap.xml
# FROM GET_DATA: Failed to retrieve http://andywilx.co.uk/robots.txt, Status Code: 404
# https://www.bridgnorthfurniture.co.uk/robots.txt  https://www.bridgnorthfurniture.co.uk/sitemap.xml
# https://www.theurbaneditions.com/robots.txt  https://www.theurbaneditions.com/sitemap.xml
# http://furniture4lettings.co.uk/robots.txt  https://lets-furnish.co.uk/sitemap.xml
# https://furnituredirectonline.co.uk/robots.txt  https://furnituredirectonline.co.uk/sitemap.xml
# https://furniturevilla.co.uk/robots.txt  https://furniturevilla.co.uk/sitemap.xml
# https://www.grandadsshedbrigg.co.uk/robots.txt  https://www.grandadsshedbrigg.co.uk/sitemap_index.xml
# https://hanchicsfurniture.co.uk/robots.txt  https://hanchicsfurniture.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching http://imaginexfurniture.uk/robots.txt: HTTPConnectionPool(host='imaginexfurniture.uk', port=80): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000204CA1BE930>: Failed to resolve 'imaginexfurniture.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://limesinteriors.co.uk/robots.txt: HTTPSConnectionPool(host='limesinteriors.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BCAA0>: Failed to resolve 'limesinteriors.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching http://m-edition.co.uk/robots.txt: HTTPConnectionPool(host='m-edition.co.uk', port=80): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000204CA1BD220>: Failed to resolve 'm-edition.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Failed to retrieve http://macquillanhome.co.uk/robots.txt, Status Code: 404
# https://www.nabisottomanfurniture.co.uk/robots.txt  https://www.nabisottomanfurniture.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://paulcaseboutique.co.uk/robots.txt: HTTPSConnectionPool(host='paulcaseboutique.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BD1F0>: Failed to resolve 'paulcaseboutique.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Failed to retrieve https://www.reckageathome.co.uk/robots.txt, Status Code: 436
# FROM GET_DATA: Error fetching https://rotherwoodfurniture.com/robots.txt: HTTPSConnectionPool(host='rotherwoodfurniture.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'rotherwoodfurniture.com'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://www.search4furniture.com/robots.txt: HTTPSConnectionPool(host='www.search4furniture.com', port=443): Max retries exceeded with url: /robots.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000204CA1BD640>, 'Connection to www.search4furniture.com timed out. (connect timeout=3)'))
# FROM GET_DATA: Error fetching https://shop4sofas.co.uk/robots.txt: HTTPSConnectionPool(host='shop4sofas.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'shop4sofas.co.uk'. (_ssl.c:1000)")))
# https://www.simplyhomeinteriors.co.uk/robots.txt  https://www.simplyhomeinteriors.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching http://www.sjdfurniture.co.uk/robots.txt: HTTPConnectionPool(host='www.sjdfurniture.co.uk', port=80): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000204CA1BFAD0>: Failed to resolve 'www.sjdfurniture.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://thedorsetfurniturecompany.co.uk/robots.txt: HTTPSConnectionPool(host='thedorsetfurniturecompany.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BD4F0>: Failed to resolve 'thedorsetfurniturecompany.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching http://thefurnitureshopblackhall.co.uk/robots.txt: HTTPConnectionPool(host='thefurnitureshopblackhall.co.uk', port=80): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000204CA1BDA00>: Failed to resolve 'thefurnitureshopblackhall.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://www.tobychairs.com/robots.txt: HTTPSConnectionPool(host='www.tobychairs.com', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C934F980>: Failed to resolve 'www.tobychairs.com' ([Errno 11001] getaddrinfo failed)"))
# https://www.littletulip.com/robots.txt  https://www.littletulip.com/sitemap.xml
# https://uniquehomefurnishing.co.uk/robots.txt  https://uniquehomefurnishing.co.uk/sitemap.xml
# https://urbansize.co.uk/robots.txt  https://urbansize.co.uk/sitemap.xml
# https://www.modernfurnituredeals.co.uk/robots.txt  https://www.modernfurnituredeals.co.uk/sitemap.xml
# https://www.abowed.co.uk/robots.txt  https://www.abowed.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://www.peterboroughreclinercentre.co.uk/robots.txt: HTTPSConnectionPool(host='www.peterboroughreclinercentre.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.peterboroughreclinercentre.co.uk'. (_ssl.c:1000)")))
# FROM GET_DATA: Failed to retrieve https://www.oaktreeupholstery.co.uk/robots.txt, Status Code: 404
# https://www.rightprice.co.uk/robots.txt  https://www.rightprice.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://www.sheridaninteriors.co.uk/robots.txt: HTTPSConnectionPool(host='www.sheridaninteriors.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.sheridaninteriors.co.uk'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://www.chattelsfurniture.co.uk/robots.txt: HTTPSConnectionPool(host='www.chattelsfurniture.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1000)')))
# https://www.maisonandgarden.co.uk/robots.txt  https://www.maisonandgarden.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://igigishop.co.uk/robots.txt: HTTPSConnectionPool(host='igigishop.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'igigishop.co.uk'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://divine-interiors.co.uk/robots.txt: HTTPSConnectionPool(host='divine-interiors.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BCB00>: Failed to resolve 'divine-interiors.co.uk' ([Errno 11001] getaddrinfo failed)"))
# https://shackletonsretail.co.uk/robots.txt  https://www.shackletonsretail.co.uk/sitemap.php
# https://auburnfox.co.uk/robots.txt  https://www.auburnfox.co.uk/sitemap.xml
# https://www.decoframe.co.uk/robots.txt  https://www.decoframe.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://snugathome.co.uk/robots.txt: HTTPSConnectionPool(host='snugathome.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BCAA0>: Failed to resolve 'snugathome.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Failed to retrieve https://ashtonandcoleman.co.uk/robots.txt, Status Code: 403
# https://rusticland.co.uk/robots.txt  https://rusticland.co.uk/sitemap.xml
# https://www.quaysideinteriors.co.uk/robots.txt  https://www.quaysideinteriors.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://alidasa.co.uk/robots.txt: HTTPSConnectionPool(host='alidasa.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BDA60>: Failed to resolve 'alidasa.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://www.lovettandjudge.co.uk/robots.txt: HTTPSConnectionPool(host='www.lovettandjudge.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BE270>: Failed to resolve 'www.lovettandjudge.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://www.toplinestore.co.uk/robots.txt: HTTPSConnectionPool(host='www.toplinestore.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.toplinestore.co.uk'. (_ssl.c:1000)")))
# FROM GET_DATA: Error fetching https://windsorbedding.co.uk/robots.txt: HTTPSConnectionPool(host='windsorbedding.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000204CA1BDFA0>, 'Connection to windsorbedding.co.uk timed out. (connect timeout=3)'))
# FROM GET_DATA: Error fetching https://www.dezilux.co.uk/robots.txt: HTTPSConnectionPool(host='www.dezilux.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BC560>: Failed to resolve 'www.dezilux.co.uk' ([Errno 11001] getaddrinfo failed)"))
# https://elegancehomefurniture.co.uk/robots.txt  https://elegancehomefurniture.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://www.homeaffections.co.uk/robots.txt: HTTPSConnectionPool(host='www.homeaffections.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BE300>: Failed to resolve 'www.homeaffections.co.uk' ([Errno 11001] getaddrinfo failed)"))
# https://hemmingandwills.co.uk/robots.txt  https://hemmingandwills.co.uk/sitemap.xml
# FROM GET_DATA: Error fetching https://jopa-interiors.co.uk/robots.txt: HTTPSConnectionPool(host='jopa-interiors.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BF320>: Failed to resolve 'jopa-interiors.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://derwenthouseliving.co.uk/robots.txt: HTTPSConnectionPool(host='derwenthouseliving.co.uk', port=443): Read timed out. (read timeout=3)
# FROM GET_DATA: Error fetching https://www.furlon.co.uk/robots.txt: HTTPSConnectionPool(host='www.furlon.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204C8672240>: Failed to resolve 'www.furlon.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://rustic-furniture.co.uk/robots.txt: HTTPSConnectionPool(host='rustic-furniture.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BD5E0>: Failed to resolve 'rustic-furniture.co.uk' ([Errno 11001] getaddrinfo failed)"))
# FROM GET_DATA: Error fetching https://www.skhomedecor.co.uk/robots.txt: HTTPSConnectionPool(host='www.skhomedecor.co.uk', port=443): Max retries exceeded with url: /robots.txt (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000204CA1BE150>: Failed to resolve 'www.skhomedecor.co.uk' ([Errno 11001] getaddrinfo failed)"))
# https://www.onlydiningchairs.com.au/robots.txt  https://www.onlydiningchairs.com.au/sitemap.xml
# https://www.myharmony.hk/robots.txt  https://www.myharmony.hk/sitemap.xml
# https://afg.us.com/robots.txt  https://afg.us.com/sitemap.xml
# https://www.collectioni.com/robots.txt  https://www.collectioni.com/sitemap.xml
# FROM GET_DATA: Failed to retrieve https://noho.co/robots.txt, Status Code: 404
# https://odafurniture.com/robots.txt  http://cunacci.com/sitemap.xml
# https://savannahspace.com/robots.txt  https://savannahspace.com/sitemap.xml
# https://squarehome.com/robots.txt  http://squarehome.com/wp-sitemap.xml
# https://www.sundays-company.com/robots.txt  https://www.sundays-company.com/sitemap.xml
# https://thebeachfurniture.com.au/robots.txt  https://thebeachfurniture.com.au/sitemap.xml
# FROM GET_DATA: Error fetching https://thedesigndepot.co.nz/robots.txt: HTTPSConnectionPool(host='thedesigndepot.co.nz', port=443): Read timed out. (read timeout=3)
# https://superdealfurnituregallery.com/robots.txt  https://sdfgallery.ca/sitemap.xml
# https://signaturefinefurniture.ca/robots.txt  https://signaturefinefurniture.ca/sitemap_index.xml
# FROM GET_DATA: Error fetching http://aonefurniture.in/robots.txt: HTTPSConnectionPool(host='aonefurniture.in', port=443): Read timed out. (read timeout=3)
# https://furnituremama.com/robots.txt  https://furnituremama.com/sitemap.xml
# https://www.mwfurnitureoutlet.com/robots.txt  https://luxhomedecor.com/sitemap.xml
# 418

# %%
# writing the sitemaps to a csv file
with open('../Data/sitemaps_robots.csv', mode='w', newline='') as file: # If I decide to use this (probably not this late and its only 30 urls better than what I have for training)
    csv_writer = csv.writer(file)
    for link in link_and_sitemap:
        csv_writer.writerow(link)

# %% [markdown]
# ## Methods that will be used for scraping the sitemaps / the websites themselves
